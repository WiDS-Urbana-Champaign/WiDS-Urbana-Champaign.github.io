# %% [markdown]
# # In Class Notebook, Week 02

# %% [markdown]
# You can access this notebook in near-real time by going here:
#
# https://github.com/UIUC-iSchool-DataViz/is445_obuobg_spring2025/blob/master/week02/inClass_week02.ipynb
#
# Or by pasting that URL into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
print("hi there!") # I hit SHIFT+RETURN as the hot key to run this
# Out:
# hi there!

# %%
"hi there, again!"
# Out:
# 'hi there, again!'

# %% [markdown]
# I hit `ESC+m` to make this a Markdown cell that I can write notes in.
#
# # This is a header!
# ## This is a smaller header
#
# I can make an unordered list with `*`:
# * thing number 1
# * thing number 2
# * thing number 3
#
# I can also make an ordered list:
# 1. first thing
# 1. second thing
#
# Quick LaTeX formatting (feel free to ignore if you wanna):
# $$y = \frac{x}{2}$$

# %%
4+5
# Out:
# 9

# %%
import pandas as pd # shorthanding the Pandas library as "pd"

# %%
# ESC+a to get a new cell above my current cell
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
buildings = pd.read_csv('https://github.com/UIUC-iSchool-DataViz/is445_data/raw/main/building_inventory.csv')

# %%
buildings
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
# subsetting by index
buildings.iloc[0:3] # <-- make note of this "i"!
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
#
#        Rep Full Name  ...  Bldg Status Year Acquired Year Constructed  \
# 0  Hammond Norine K.  ...       In Use          1975             1975
# 1  Hammond Norine K.  ...       In Use          2004             2004
# ...

# %%
buildings.iloc[100:103]['Agency Name']
# Out:
# 100    Department of Natural Resources
# 101    Department of Natural Resources
# 102    Department of Natural Resources
# Name: Agency Name, dtype: object

# %%
type(buildings)
# Out:
# pandas.core.frame.DataFrame

# %%
type(buildings.iloc[100:103]['Agency Name'])
# Out:
# pandas.core.series.Series

# %%
# how many unique "Agency Name" values are there in this dataset?
buildings['Agency Name'].nunique()
# Out:
# 35

# %%
buildings['Bldg Status'].unique()
# Out:
# array(['In Use', 'Abandon', 'In Progress'], dtype=object)

# %%
# what columns are in this dataset?
buildings.columns
# Out:
# Index(['Agency Name', 'Location Name', 'Address', 'City', 'Zip code', 'County',
#        'Congress Dist', 'Congressional Full Name', 'Rep Dist', 'Rep Full Name',
#        'Senate Dist', 'Senator Full Name', 'Bldg Status', 'Year Acquired',
#        'Year Constructed', 'Square Footage', 'Total Floors',
#        'Floors Above Grade', 'Floors Below Grade', 'Usage Description',
#        'Usage Description 2', 'Usage Description 3'],
#       dtype='object')

# %%
buildings.describe()
# Out:
#            Zip code  Congress Dist     Rep Dist  Senate Dist  Year Acquired  \
# count   8862.000000    8862.000000  8862.000000  8862.000000    8862.000000
# mean   61821.076845      13.404085    92.303318    46.408599    1913.267660
# std     1095.203357       4.037936    23.568457    11.781038     337.024796
# min     1235.000000       0.000000     0.000000     0.000000       0.000000
# 25%    61105.000000      12.000000    79.000000    40.000000    1957.000000
# 50%    62023.000000      14.000000    97.000000    49.000000    1975.000000
# 75%    62650.000000      16.000000   110.000000    55.000000    1992.000000
# max    68297.000000      18.000000   119.000000    60.000000    2019.000000
#
#        Year Constructed  Square Footage  Total Floors  Floors Above Grade  \
# count       8862.000000    8.862000e+03   8862.000000         8862.000000
# mean        1906.135184    1.147603e+04      1.636087            1.449334
# ...

# %%
# let's look at all the rows that have 0 square footage
buildings.loc[buildings['Square Footage'] == 0] # boolean operation to filter by 0 sq footage
# Out:
#                           Agency Name  \
# 74    Department of Natural Resources
# 76    Department of Natural Resources
# 181         Department of Corrections
# 333      Department of Transportation
# 421      Northern Illinois University
# 422      Northern Illinois University
# 507   Department of Natural Resources
# 540         Department of Agriculture
# 551   Department of Natural Resources
# 552   Department of Natural Resources
# 805   Department of Natural Resources
# 1064     Department of Transportation
# 1148  Department of Natural Resources
# 1149  Department of Natural Resources
# 1151  Department of Natural Resources
# 1163  Department of Natural Resources
# 1473  Department of Natural Resources
# 1827  Department of Natural Resources
# 2289     Department of Human Services
# 2290     Department of Human Services
# 2291     Department of Human Services
# 2384  Department of Natural Resources
# 2385  Department of Natural Resources
# ...

# %%
buildings[buildings['Square Footage'] == 0]
# Out:
#                           Agency Name  \
# 74    Department of Natural Resources
# 76    Department of Natural Resources
# 181         Department of Corrections
# 333      Department of Transportation
# 421      Northern Illinois University
# 422      Northern Illinois University
# 507   Department of Natural Resources
# 540         Department of Agriculture
# 551   Department of Natural Resources
# 552   Department of Natural Resources
# 805   Department of Natural Resources
# 1064     Department of Transportation
# 1148  Department of Natural Resources
# 1149  Department of Natural Resources
# 1151  Department of Natural Resources
# 1163  Department of Natural Resources
# 1473  Department of Natural Resources
# 1827  Department of Natural Resources
# 2289     Department of Human Services
# 2290     Department of Human Services
# 2291     Department of Human Services
# 2384  Department of Natural Resources
# 2385  Department of Natural Resources
# ...

# %%
buildings['Square Footage'].plot()
# Out:
# <AxesSubplot:>

# %%
buildings['Square Footage'].min()
# Out:
# 0

# %%
buildings['Year Acquired'].min()
# Out:
# 0

# %%
buildings['Year Constructed'].min()
# Out:
# 0

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
# ...

# %%
buildings = pd.read_csv('https://github.com/UIUC-iSchool-DataViz/is445_data/raw/main/building_inventory.csv',
                       na_values = {
                           'Square Footage': 0,
                           'Year Constructed': 0,
                           'Year Acquired': 0
                       })

# %%
buildings['Square Footage'].min()
# Out:
# 9.0

# %%
buildings['Year Constructed'].min()
# Out:
# 1753.0

# %%
buildings['Square Footage'].plot()
# Out:
# <AxesSubplot:>

# %%
buildings['Year Acquired'].plot()
# Out:
# <AxesSubplot:>

# %%
buildings['Year Acquired'].plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 buildings['Year Acquired'].plot(kind='scatter')
#
# File /opt/anaconda3/envs/DataViz2/lib/python3.10/site-packages/pandas/plotting/_core.py:977, in PlotAccessor.__call__(self, *args, **kwargs)
#     975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
# --> 977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#     978 elif kind in self._series_kinds:
#     979     if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
buildings['Year Acquired']
# Out:
# 0       1975.0
# 1       2004.0
# 2       2004.0
# 3       2004.0
# 4       2004.0
#          ...
# 8857       NaN
# 8858       NaN
# 8859       NaN
# 8860    1971.0
# 8861       NaN
# Name: Year Acquired, Length: 8862, dtype: float64

# %%
#buildings['Year Acquired'].plot(kind='scatter')
buildings.plot(x='Year Acquired', y='Square Footage', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Year Acquired', ylabel='Square Footage'>

# %%
ax = buildings.plot(x='Year Acquired', y='Square Footage', kind='scatter')
ax.set_yscale('log')

# %%
import matplotlib.pyplot as plt

# %%
# old plot
# ax = buildings.plot(x='Year Acquired', y='Square Footage', kind='scatter')
# ax.set_yscale('log')
# on a mac: COMMAND + /
# on a windows: CTRL + /
fig, ax = plt.subplots(figsize=(10,2))
buildings.plot(x='Year Acquired', y='Square Footage', kind='scatter', ax=ax)
ax.set_yscale('log')

# %%
buildings['Bldg Status'].unique()
# Out:
# array(['In Use', 'Abandon', 'In Progress'], dtype=object)

# %%
buildings.groupby('Bldg Status')

# %%
for status, group in buildings.groupby('Bldg Status'):
    print(status)
# Out:
# Abandon
# In Progress
# In Use

# %%
for group in buildings.groupby('Bldg Status'):
    print(group)
# Out:
# ('Abandon',                                     Agency Name  \
# 381                Department of Human Services
# 449             Department of Natural Resources
# 1050            Department of Natural Resources
# 1139  Department of Central Management Services
# 1172            Department of Natural Resources
# ...                                         ...
# 8682             Department of Military Affairs
# 8683             Department of Military Affairs
# 8760               Historic Preservation Agency
# 8800             Department of Military Affairs
# 8801             Department of Military Affairs
#
#                                          Location Name  \
# 381        Lincoln Developmental Center - Logan County
# 449       Clinton Lake Recreation Area - DeWitt County
# 1050           Jim Edgar Panther Creek F&WA - Cass Co.
# 1139                                 Statewide Program
# 1172   Saline County Conservation Area - Saline County
# ...

# %%
for status, df_group in buildings.groupby('Bldg Status'):
    print(status, df_group.shape)
# Out:
# Abandon (226, 22)
# In Progress (113, 22)
# In Use (8523, 22)

# %%
buildings.shape
# Out:
# (8862, 22)

# %%
for status, df_group in buildings.groupby('Year Acquired'):
    print(status, df_group.shape)
# Out:
# 1753.0 (1, 22)
# 1802.0 (2, 22)
# 1810.0 (3, 22)
# 1832.0 (1, 22)
# 1837.0 (1, 22)
# 1838.0 (1, 22)
# 1839.0 (1, 22)
# 1840.0 (8, 22)
# 1841.0 (1, 22)
# 1843.0 (1, 22)
# 1844.0 (1, 22)
# 1845.0 (3, 22)
# 1848.0 (4, 22)
# 1850.0 (2, 22)
# 1853.0 (1, 22)
# 1854.0 (1, 22)
# 1855.0 (6, 22)
# 1856.0 (1, 22)
# 1857.0 (2, 22)
# 1858.0 (2, 22)
# 1859.0 (1, 22)
# 1860.0 (6, 22)
# 1863.0 (1, 22)
# 1865.0 (9, 22)
# 1867.0 (1, 22)
# 1870.0 (1, 22)
# 1871.0 (5, 22)
# 1872.0 (1, 22)
# 1873.0 (1, 22)
# 1874.0 (1, 22)
# 1875.0 (3, 22)
# 1876.0 (5, 22)
# 1878.0 (1, 22)
# 1880.0 (8, 22)
# 1881.0 (1, 22)
# 1882.0 (2, 22)
# 1883.0 (2, 22)
# 1885.0 (4, 22)
# 1886.0 (13, 22)
# 1887.0 (4, 22)
# 1888.0 (2, 22)
# 1890.0 (7, 22)
# 1891.0 (1, 22)
# 1892.0 (3, 22)
# 1893.0 (6, 22)
# 1894.0 (1, 22)
# 1895.0 (7, 22)
# 1896.0 (6, 22)
# 1897.0 (1, 22)
# 1898.0 (2, 22)
# 1899.0 (3, 22)
# 1900.0 (27, 22)
# 1901.0 (3, 22)
# 1902.0 (8, 22)
# 1903.0 (6, 22)
# 1904.0 (7, 22)
# 1905.0 (13, 22)
# 1906.0 (2, 22)
# ...

# %%
# how much square footage was acquired per year?
buildings.groupby('Year Acquired')['Square Footage'].sum()
# Out:
# Year Acquired
# 1753.0      1200.0
# 1802.0      4440.0
# 1810.0      4033.0
# 1832.0    120000.0
# 1837.0     10302.0
#             ...
# 2015.0    305093.0
# 2016.0    304839.0
# 2017.0      6720.0
# 2018.0     17160.0
# 2019.0      1520.0
# Name: Square Footage, Length: 171, dtype: float64

# %%
# plot the total square footage per year acquired
fig, ax = plt.subplots(figsize=(10,2))
gbs = buildings.groupby('Year Acquired')['Square Footage'].sum()
gbs.plot(ax=ax)
ax.set_yscale('log')
ax.set_ylabel('Square Footage')
plt.show()

# %%
x = gbs.index.values
x
# Out:
# array([1753., 1802., 1810., 1832., 1837., 1838., 1839., 1840., 1841.,
#        1843., 1844., 1845., 1848., 1850., 1853., 1854., 1855., 1856.,
#        1857., 1858., 1859., 1860., 1863., 1865., 1867., 1870., 1871.,
#        1872., 1873., 1874., 1875., 1876., 1878., 1880., 1881., 1882.,
#        1883., 1885., 1886., 1887., 1888., 1890., 1891., 1892., 1893.,
#        1894., 1895., 1896., 1897., 1898., 1899., 1900., 1901., 1902.,
#        1903., 1904., 1905., 1906., 1907., 1908., 1909., 1910., 1911.,
#        1912., 1913., 1914., 1915., 1916., 1917., 1918., 1919., 1920.,
#        1921., 1922., 1923., 1924., 1925., 1926., 1927., 1928., 1929.,
#        1930., 1931., 1932., 1933., 1934., 1935., 1936., 1937., 1938.,
#        1939., 1940., 1941., 1942., 1943., 1944., 1945., 1946., 1947.,
#        1948., 1949., 1950., 1951., 1952., 1953., 1954., 1955., 1956.,
#        1957., 1958., 1959., 1960., 1961., 1962., 1963., 1964., 1965.,
# ...

# %%
y = gbs.values
y
# Out:
# array([1.200000e+03, 4.440000e+03, 4.033000e+03, 1.200000e+05,
#        1.030200e+04, 2.010000e+03, 1.175200e+04, 3.691800e+04,
#        3.256000e+03, 9.000000e+02, 4.088000e+03, 6.584600e+04,
#        2.129200e+04, 2.267000e+03, 2.550000e+05, 2.140000e+03,
#        6.615400e+04, 7.500000e+02, 1.812400e+04, 2.236700e+04,
#        4.847000e+03, 2.741700e+04, 1.579500e+04, 2.234940e+05,
#        2.700000e+03, 2.864000e+03, 6.403000e+03, 1.490000e+04,
#        1.100000e+04, 6.600000e+03, 3.808000e+03, 4.042800e+05,
#        3.307100e+04, 1.798330e+05, 6.671000e+03, 5.926600e+04,
#        8.725000e+03, 3.015700e+04, 1.683700e+05, 1.948230e+05,
#        8.492400e+04, 8.633400e+04, 2.325000e+03, 1.514800e+05,
#        3.959000e+04, 8.500000e+04, 2.256770e+05, 2.901650e+05,
#        1.329070e+05, 3.676000e+04, 1.214750e+05, 3.358350e+05,
#        1.094860e+05, 2.697250e+05, 1.605840e+05, 4.096400e+04,
#        3.128860e+05, 2.037400e+04, 1.332850e+05, 3.602520e+05,
# ...

# %%
# plot the total square footage per year acquired
fig, ax = plt.subplots(figsize=(10,2))
gbs = buildings.groupby('Year Acquired')['Square Footage'].sum()
#gbs.plot(ax=ax)
ax.plot(x, y)
ax.set_yscale('log')
ax.set_ylabel('Square Footage')
ax.set_xlabel('Year Acquired')
plt.show()

# %%
stats = buildings.groupby('Year Acquired')['Square Footage'].describe()
stats
# Out:
#                count           mean           std       min       25%  \
# Year Acquired
# 1753.0           1.0    1200.000000           NaN    1200.0    1200.0
# 1802.0           2.0    2220.000000   1943.129435     846.0    1533.0
# 1810.0           3.0    1344.333333   1809.945948     216.0     300.5
# 1832.0           1.0  120000.000000           NaN  120000.0  120000.0
# 1837.0           1.0   10302.000000           NaN   10302.0   10302.0
# ...              ...            ...           ...       ...       ...
# 2015.0          20.0   15254.650000  29153.085290     144.0     696.0
# 2016.0          10.0   30483.900000  61864.180491    1152.0    2464.0
# 2017.0           1.0    6720.000000           NaN    6720.0    6720.0
# 2018.0           4.0    4290.000000   5153.644342    1455.0    1455.0
# 2019.0           2.0     760.000000      0.000000     760.0     760.0
#
#                     50%        75%       max
# Year Acquired
# 1753.0           1200.0    1200.00    1200.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.plot(stats['max'], marker='.')
ax.set_xlabel('Year Acquired')
ax.set_ylabel('Square Footage (max)')
ax.set_yscale('log')
plt.show()

# %%
buildings['Zip code']
# Out:
# 0       61501
# 1       61501
# 2       61501
# 3       61501
# 4       61501
#         ...
# 8857    61008
# 8858    61008
# 8859    62305
# 8860    61348
# 8861    61607
# Name: Zip code, Length: 8862, dtype: int64

# %%
buildings['Zip code'].value_counts()
# Out:
# Zip code
# 62702    264
# 62901    259
# 62037    235
# 61801    215
# 62958    199
#         ...
# 62012      1
# 62844      1
# 62882      1
# 62418      1
# 61073      1
# Name: count, Length: 461, dtype: int64

# %%
buildings['Zip code'].value_counts().iloc[0:5]
# Out:
# Zip code
# 62702    264
# 62901    259
# 62037    235
# 61801    215
# 62958    199
# Name: count, dtype: int64

# %%
buildings['Zip code'].value_counts().iloc[0:5].index.values
# hint 2 for lab: check out the .isin function :)
# Out:
# array([62702, 62901, 62037, 61801, 62958])

# %%
# bar plot practice with a groupby
gbs2 = buildings.groupby('Bldg Status')['Year Acquired'].min()

# %%
gbs2
# Out:
# Bldg Status
# Abandon        1880.0
# In Progress    2008.0
# In Use         1753.0
# Name: Year Acquired, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,2))
gbs2.plot(kind='bar', ax=ax)
plt.show()
