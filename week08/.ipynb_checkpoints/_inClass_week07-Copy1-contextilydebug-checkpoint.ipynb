# %% [markdown]
# # debug

# %% [markdown]
# ## On to geopandas!

# %%
import geopandas

# %%
gdf_apt = geopandas.read_file('https://gisportal.champaignil.gov/ms/rest/services/Open_Data/Open_Data/MapServer/8/query?outFields=*&where=1%3D1&f=geojson')

# %%
gdf_ez = geopandas.read_file('https://gisportal.champaignil.gov/ms/rest/services/Open_Data/Open_Data/MapServer/3/query?outFields=*&where=1%3D1&f=geojson')

# %%
import matplotlib.pyplot as plt

# %%
import contextily as ctx

# %%
fig, ax = plt.subplots(figsize=(10,10))
gdf_apt.plot(ax=ax, column='Building_Type', cmap='rainbow', legend=True)
gdf_ez.plot(ax=ax, alpha=0.5)
ctx.add_basemap(ax=ax, crs=gdf_ez.crs)

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)
plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)

gdf_ez.plot(ax=ax, alpha=0.5, edgecolor='k')
gdf_apt.plot(column='Building_Type', ax=ax, cmap='rainbow')

#https://github.com/geopandas/contextily/issues/223
ctx.add_basemap(ax=ax, crs=gdf_ez.crs, source=cx.providers.OpenStreetMap.Mapnik)#.to_string())


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 9
#       6 gdf_ez.plot(ax=ax, alpha=0.5, edgecolor='k')
#       7 gdf_apt.plot(column='Building_Type', ax=ax, cmap='rainbow')
# ----> 9 ctx.add_basemap(ax=ax, crs=gdf_ez.crs)#.to_string())
#      12 plt.show()
#
# File ~/opt/anaconda3/envs/DataVizPL/lib/python3.8/site-packages/contextily/plotting.py:129, in add_basemap(ax, zoom, source, interpolation, attribution, attribution_size, reset_extent, crs, resampling, **extra_imshow_args)
#     125     left, right, bottom, top = _reproj_bb(
#     126         left, right, bottom, top, crs, {"init": "epsg:3857"}
#     127     )
#     128 # Download image
# --> 129 image, extent = bounds2img(
#     130     left, bottom, right, top, zoom=zoom, source=source, ll=False
#     131 )
#     132 # Warping
#     133 if crs is not None:
#
# File ~/opt/anaconda3/envs/DataVizPL/lib/python3.8/site-packages/contextily/tile.py:225, in bounds2img(w, s, e, n, zoom, source, ll, wait, max_retries)
#     223     tiles.append(t)
#     224     arrays.append(image)
# --> 225 merged, extent = _merge_tiles(tiles, arrays)
#     226 # lon/lat extent --> Spheric Mercator
#     227 west, south, east, north = extent
#
# File ~/opt/anaconda3/envs/DataVizPL/lib/python3.8/site-packages/contextily/tile.py:628, in _merge_tiles(tiles, arrays)
#     626 for ind, arr in zip(indices, arrays):
#     627     x, y = ind
# --> 628     img[y * h : (y + 1) * h, x * w : (x + 1) * w, :] = arr
#     630 bounds = np.array([mt.bounds(t) for t in tiles])
#     631 west, south, east, north = (
#     632     min(bounds[:, 0]),
#     633     min(bounds[:, 1]),
#     634     max(bounds[:, 2]),
#     635     max(bounds[:, 3]),
#     636 )
#
# ValueError: could not broadcast input array from shape (512,512,4) into shape (256,256,4)

# %%
gdf_ez.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_apt.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
